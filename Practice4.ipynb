# %% [markdown]
# <div align='center'>
# МІНІСТЕРСТВО ОСВІТИ І НАУКИ УКРАЇНИ
#
# Національний аерокосмічний університет ім. М.Є.Жуковського
# "Харківський авіаційний інститут"
#
# Факультет радіотехніки, комп’ютерних систем і інфокомунікацій
#
# Кафедра інформаційно-комунікаційних технологій ім. О. О. Зеленського
#
#
# ПРАКТИЧНА РОБОТА №4
#
# з курсу "Захист інформації в інфокомунікаціях"
#
# на тему "Пошук мережевих вразливостей кінцевого пристрою"
#
# <div align='right'>
# Виконав: студент ??? курсу
#
# групи № ???
#
# спеціальності 172 "Телекомунікації та радіотехника" / 126 "Інформаційні системи і технології" (залишити необхідне)
#
# Прізвище та ініціали
#
# Прийняв: (вказати посаду)
#
# Прізвище та ініціали викладача
#
# Національна шкала: __________
#
# Кількість балів: _____
#
# Оцінка: ECTS _____
# </div>
#
# Харків - 2023
# </div>

# %% [markdown]
# ## Практична робота №4. Пошук мережевих вразливостей кінцевого пристрою
#
# **Мета роботи**: ознайомитися з синтаксисом мови програмування Python і бібліотеки Scapy, скласти скрипт для сканування активних пристроїв мережі з використанням різних мережних протоколів.
#
# ### Зміст
#
# - Частина 1. Вивчення ПЗ Nmap і сканування мережі
# - Частина 2. Використання протоколів ARP, TCP і UDP для сканування мережі і пристроїв

# %% [markdown]
# ### Частина 1. Вивчення ПЗ Nmap і сканування мережі

# %% [markdown]
# **Завдання** - сканування мережі за допомогою Nmap
#
# Nmap - програмне забезпечення для дослідження та аудиту безпеки мереж та виявлення активних мережних сервісів. \
# Nmap використовує як протокол ICMP, так і TCP, UDP та інші.
#
# **Крок 1. Встановити nmap**
# - для Windows - завантажити зі сторінки <https://nmap.org/download.html>
# - для Linux - в терміналі виконати команди
#     - для дистрибутивів на основі Debian/Ubuntu: `sudo apt install nmap`
#     - для дистрибутивів на основі RedHat: `sudo dnf install nmap`
#     - або слідувати інструкції зі сторінки <https://nmap.org/download.html>
#
# **Крок 2. Ознайомитися з можливостями Nmap** \
# Запустити з командного рядка та вивчити можливості програми. `Help` та інструкцію з використання можна вивести за командою:

# %%
# !nmap -h

# %% [markdown]
# **Крок 3. Визначити в мережевих налаштуваннях мережну адресу пристрою і мережі в цілому** \
# Команди командного рядка(терміналу) для визначення налаштувань мережі:
# - для Windows - `ipconfig /all`
# - для Linux - `ip -br addr`
# - або зайти в графічний інтерфейс налаштувань мережі

# %%
# !ip addr

# %% [markdown]
# **Крок 4. Просканувати свою мережу** \
# Приклади опцій з кроку №2:
# - Ключ `-v` ... `-vvvvv` вказує на різний рівень відображення інформації про сканування
# - Ключ `-A` вказує на запуск скриптів з визначення версій ОС та ПЗ ("Enable OS detection, version detection, script scanning, and traceroute")

# %%
# !nmap ключі адреса_мережі/префікс_мережі

# %% [markdown]
# **Крок 5. Привести в звіті результати роботи Nmap**
#
# Навести в звіті налаштування мережі і результати виконання команд програмою Nmap \
# *Не потрібно у разі використання даного шаблону jupyter-notebook*

# %% [markdown]
# ### Частина 2. Використання протоколів ARP, TCP і UDP для сканування мережі і пристроїв

# %% [markdown]
# **Завдання** - провести сканування власної мережі і виявити працюючі вузли і TCP-служби в них. Реалізувати завдання за допомогою Python i Scapy
#
# **Крок 1. Виконати ICMP або ARP запити на всі вузли мережі**
#
# Рекомендації: \
# - Для уникнення нескінченного очікування на відповідь від неіснуючих вузлів встановіть `timeout` на 2 секунди або менше
# - ARP-запит дозволяє охопити всю мережу однією командою
# - ICMP-запит потребує попереднього ARP-запиту для визначення МАС-адреси. Для зменешення затримок на визначення МАС-адреси неіснуючих вузлів можна відразу відправляти широкомовні запити з МАС-адресою отримувача 'ff:ff:ff:ff:ff:ff'

# %%
ans, un = 
ans.show()

# %% [markdown]
# Вивести перелік виключно активних вузлів мережі:

# %% [markdown]
# **Крок 2. Зробити TCP-scanning** \
# Для активних вузлів зробити TCP-scanning використовуючи SYN-ключ (в матеріалах лекції та на офіційній сторінці Scapy). \
# Щонайменше мають бути перевірені порти 20-150 і 443, бажано до 1000. Якщо використовуються сервери баз даних, то варто і їх включити у перелік портів, що скануються

# %% [markdown]
# Вивести перелік активних ТСР-портів, використовуючи наступну підказку з документації:

# %%
ans.nsummary( lfilter=lambda s,r: (r.haslayer(TCP) and (r.getlayer(TCP).flags & 2)) )

# %% [markdown]
# **Крок 3. Навести в звіті результати роботи по завданню №2**
#
# *Не потрібно у разі виконанні завдання у даному шаблоні jupyter-notebook*

# %% [markdown]
# ### Частина 3. Перевірка роботи служби DNS

# %% [markdown]
# **Завдання** - перевірити роботу служби DNS локальної мережі
#
# **DNS** - служба доменних імен, що забезпечує перетворення доменного імені певного сайту на його ІР-адресу. Для цього використовується одноіменний протокол 7-го рівня, що інкапсулюється в UDP-дейтаграми з портом призначення рівним 53.
#
#
# **Крок 1. Обрати адресу призначення за варіантом по списку**
#
# Відповідно до порядкового номеру в списку групи оберіть сайт для виконання роботи
#
# |Варіант|Сайт|
# |---|---|
# |1|google.com|
# |2|yahoo.com|
# |3|facebook.com|
# |4|python.org|
# |5|youtube.com|
# |6|wikipedia.org|
# |7|amazon.com|
# |8|live.com|
# |9|bing.com|
# |10|instagram.com|
# |11|stackoverflow.com|
# |12|whatsapp.com|
# |13|twitter.com|
# |14|telegram.com|
# |15|viber.com|
# |16|ukr.net|
# |17|accuweather.com|
# |18|sinoptik.ua|
# |19|gismeteo.ua|
# |20|i.ua|
# |21|www.netacad.com|
#
# **Крок 2. Застосуйте nslookup** \
# В усіх операційних системах для перевірки роботи і служби DNS і визначення ІР-адреси використовується службова утиліта nslookup

# %%
# !nslookup назва_сайту

# %% [markdown]
# **Крок 3. Реалізація запиту через Scapy** \
# Створіть і відправте пакет на маршрутизатор використовуючи протоколи UDP і DNS для компонування пакету

# %%
ans = sr1(IP(dst="192.168.31.1")/UDP(sport=RandShort(), dport=53)/
DNS(rd=1,qd=DNSQR(qname="google.com",qtype="A")))

# %% [markdown]
# 1. Виведіть з заголовків пакету значення домменного імені, що задавалося, і йому відповідну ІР-адресу.
# 2. Порівняйте результат з командою nslookup

# %% [markdown]
# **Крок 4. Навести в звіті результати роботи**
#
# *Не потрібно у разі виконанні завдання у даному шаблоні jupyter-notebook*

# %% [markdown]
# ### Частина 4. Визначення маршруту до вузла

# %% [markdown]
# **Завдання** - для вузла, обраного в частині №3 виконати запит на трасування маршруту
#
# **Крок 1. Використання traceroute** \
# Зробити запит, використовуючи системну утиліту `tracert` (Windows) або `traceroute` (Linux)

# %%
# !traceroute назва_сайту
# Out:
# traceroute to google.com (142.250.203.142), 30 hops max, 60 byte packets
#  1  XiaoQiang (192.168.31.1)  1.578 ms  1.550 ms  1.538 ms
#  2  * * *
#  3  10.12.202.9 (10.12.202.9)  9.389 ms  9.379 ms  9.368 ms
#  4  226.3.86.109.triolan.net (109.86.3.226)  16.574 ms  10.346 ms  10.336 ms
#  5  108.170.248.155 (108.170.248.155)  10.324 ms 108.170.248.138 (108.170.248.138)  10.304 ms 108.170.248.155 (108.170.248.155)  10.303 ms
#  6  142.251.242.39 (142.251.242.39)  23.922 ms 142.251.242.35 (142.251.242.35)  22.811 ms  22.789 ms
#  7  142.250.37.193 (142.250.37.193)  23.431 ms 142.251.242.37 (142.251.242.37)  24.663 ms 142.250.37.193 (142.250.37.193)  23.632 ms
#  8  72.14.237.17 (72.14.237.17)  23.623 ms 142.250.37.209 (142.250.37.209)  23.728 ms 209.85.253.225 (209.85.253.225)  22.638 ms
#  9  waw07s06-in-f14.1e100.net (142.250.203.142)  23.693 ms  23.686 ms 209.85.253.225 (209.85.253.225)  22.616 ms

# %% [markdown]
# **Крок 2. Реалізувати за допомогою Scapy** \
# Трасування забезпечується покроковим збільшенням поля `ttl`. Тоді маршрутизатор, на якому обнуляється дозволена кількість переходів повертає службове ІСМР-повідомлення про відкидання даного пакета.
#
# Відтворіть попередню команду використовуючи:
# 1. Сніфінг з попередньої практики для замірювання часу
# 2. Інкріментне збільшення поля `ttl`
# 3. DNS-запити для визначення доменного імені маршрутизатора кожного переходу. Бажано ознайомитися з PTR-записом і зворотнім перетворенням ІР-адреси у доменне ім'я.
#
# \*Можливо часткове виконання даної задачі (кожна опція - "+5" балів)

# %% [markdown]
# **Крок 3. Навести в звіті результати роботи**
#
# *Не потрібно у разі виконанні завдання у даному шаблоні jupyter-notebook*
