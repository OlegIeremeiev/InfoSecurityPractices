# %% [markdown]
# <div align='center'>
# МІНІСТЕРСТВО ОСВІТИ І НАУКИ УКРАЇНИ
#
# Національний аерокосмічний університет ім. М.Є.Жуковського
# "Харківський авіаційний інститут"
#
# Факультет радіотехніки, комп’ютерних систем і інфокомунікацій
#
# Кафедра інформаційно-комунікаційних технологій ім. О. О. Зеленського
#
#
# ПРАКТИЧНА РОБОТА №5
#
# з курсу "Захист інформації в інфокомунікаціях"
#
# на тему "Шифрування інформації симетричним шифром AES"
#
# <div align='right'>
# Виконав: студент ??? курсу
#
# групи № ???
#
# спеціальності 172 "Телекомунікації та радіотехника" / 126 "Інформаційні системи і технології" (залишити необхідне)
#
# Прізвище та ініціали
#
# Прийняв: (вказати посаду)
#
# Прізвище та ініціали викладача
#
# Національна шкала: __________
#
# Кількість балів: _____
#
# Оцінка: ECTS _____
# </div>
#
# Харків - 2023
# </div>

# %% [markdown]
# ## Практична робота №5
#
# **Мета роботи**: Запрограмувати процедуру шифрування та розшифрування повідомлення, використовуючи алгоритм AES з пакету PyCryptodome
#
# **Вихідні дані**: інструкції та рекомендації щодо створення програми.
#
# **Результат**: реалізовані на принципах ООП об’єкти, що відображають відправника і отримувача зашифрованої інформації та задокументований результат їх роботи.

# %% [markdown]
# ### Теоретичні основи
#
# Криптографія і алгоритми шифрування є основним інструментом забезпечення конфіденційності інформації при передачі, а також одним із основних при її зберіганні.
#
# Виділяють два класи криптоалгоритмів (алгоритмів шифрування):
# - **Симетричні алгоритми** використовують один і той самий заздалегідь відомий ключ для шифрування і розшифрування даних.
# - **Асиметричні алгоритми** шифрування (або алгоритми шифрування з відкритим ключем) використовують один ключ для шифрування даних, а іншій ключ для розшифрування даних. Один з ключів є відкритим, а інший - закритим.
#
# В поточній роботі розглядається симетричний алгоритм шифрування AES.

# %% [markdown]
# #### Необхідне програмне забезпечення
#
# **PyCryptodome** - бібліотека мови програмування Python, що містить найбільш поширені алгоритми і методи криптографії (в якості альтернативи можуть розглядатися і інші існуючі пакети за умови самостійного їх вивчення).
#
# **Встановлення**: `pip install pycryptodome`

# %% [markdown]
# ### Практична частина
#
# **Завдання**:
# 1. Використовуючи бібліотеку PyCryptodome забезпечити процес шифрування і розшифрування даних з використанням алгоритму `AES`.
# 2. На основі підходу об'єктно-орієнтованого програмування створити два класи, що моделюють дії відправника і отримувача інформації з забезпечення шифрування і безпечної передачі даних:
#    1. Створення об'єктів, що виступають у ролі відправника і отримувача повідомлення
#    2. Формування ключа шифрування довжиною 128 біт ініціатором обміну інформацією (необхідно обрати правильний об'єкт)
#    3. Передача ключа іншому учаснику обміну інформацією
#    4. Шифрування повідомлення і його передача іншому учаснику обміну інформацією (необхідно обрати правильний об'єкт)
#    5. Розшифрування повідомлення (необхідно обрати правильний об'єкт)
#    6. Демонстрація повідомлення до шифрування, передачу зашифрованого повідомлення і повідомлення після розшифрування.
#
# Приклад для реалізації (найменування класів і методів, перелік необхідних методів і властивостей визначаєте самостійно):
#
# ```python
# class CryptoSystem:
#
#     # Створення і обмін ключем
#     def generate_key():
#         pass
#     def get_key() -> bytes:
#         pass
#         # return key
#     def set_key(key:bytes):
#         pass
#
#     # Шифрування і розшифрування повідомлення
#     def encrypt(text:str) -> bytes:
#         pass
#         # return encrypted_text
#     def decrypt(encrypted_text: bytes) -> str:
#         pass
#         # return decrypted_text
#
#     # ... інші методи відповідно до завдання
#
# class Sender(CryptoSystem):
#     pass
#
# class Receiver(CryptoSystem):
#     pass
# ```

# %% [markdown]
# ##### Крок 1. Встановлення PyCryptodome
# Встановити необхідний пакет для виконання роботи

# %%
# !pip install pycryptodome

# %% [markdown]
# ##### Крок 2. Створення об'єкта відправника
# 1. Створити об'єкт, що представляє собою відправника інформації (наприклад, `Sender`)
# 2. Наповнити його необхідними методами та атрибутами (наприклад `key` та іншими)

# %% [markdown]
# ##### Крок 3. Створення об'єкта отримувача
# 1. Створити об'єкт, що представляє собою отримувача інформації (наприклад, `Receiver`)
# 2. Наповнити його необхідними методами та атрибутами (наприклад `key` та іншими)

# %% [markdown]
# ##### Крок 4. Формування ключ шифрування
# 1. Сформувати ключ шифрування довжиною 128 біт, наприклад, використовуючи функцію генерації заданої довжини:
# ```python
# from Crypto import Random
# sessionkey = Random.new().read(16) # в байтах
# ```
# або менш безпечний варіант стандартної бібліотеки Python:
# ```python
# import random
# sessionkey = random.getrandbits(128)
# ```
#
# 2. Реалізувати метод створення ключів у правильному з двох об'єктів

# %% [markdown]
# ##### Крок 5. Створення функції шифрування
#
# Створити у відповідному об'єкті функцію шифрування повідомлення `encrypt()`, використовуючи як приклад фрагмент коду для алгоритму шифрування **AES** і метода зчеплення блоків **CFB**:
#
# ```python
# from Crypto.Cipher import AES
#
# iv = Random.new().read(16) # 128 bit
# obj = AES.new(sessionkey, AES.MODE_CFB, iv)
# encrypted_text = iv + obj.encrypt(text)
# ```

# %% [markdown]
# ##### Крок 6 Створення функції розшифрування
#
# Створити у відповідному об'єкті функцію розшифрування повідомлення `decrypt()`, використовуючи як приклад фрагмент коду для алгоритму шифрування **AES** і метода зчеплення блоків **CFB**:
#
# ```python
# iv = encrypted_text[:16]
# obj = AES.new(sessionkey, AES.MODE_CFB, iv)
# decrypted_text = obj.decrypt(encrypted_text)
# decrypted_text = decrypted_text[16:]
# ```

# %% [markdown]
# ##### Крок 7. Створення повідомлення і демонстрація процесу шифрування
# 1. Створити повідомлення, зокрема це може бути рядок з ПІБ
# 2. Використовуючи реалізовані класи і їх методи продемонструвати процес передачі ключа і подальшої безпечної передачі повідомлення з використанням шифрування
# 3. Показати значення початкового тексту (бажано як рядка і байтової послідовності), значення зашифрованого і розшифрованого повідомлення.

# %% [markdown]
# ##### Крок 8. Оформити звіт
# Оформити звіт (або використати даний шаблон jupyter notebook) з демонстрацією роботи коду. Обов'язково відображення значення початкового повідомлення, зашифрованого і розшифрованого повідомлення у початковому (крім зашифрованого) і hex-представленні.

# %% [markdown]
# **Оцінка за базове завдання** (60 балів):
# - Створені класи  - **до 45 балів**
# - Належним чином підготовлений звіт з титульною сторінкою (або шаблон jupyter notebook) і демонстрацією виконаної роботи - **до 15 балів**
#
# **Бонусні завдання**:
# 1. Можливість шифрування і розшифрування файлу з інформацією, додаючи атрибути з назвою файлів початкового, зашифрованого і розшифрованого повідомлення - **до 10 балів**
#
# Фрагменти коду, що можуть бути у нагоді:
#
# Зчитування інформації:
# ```python
# f = open('path_to_folder\\messagefile.txt','rb')
# text = f.read()
# f.close()
# ```
# Запис у файл
# ```python
# f = open('path_to_folder\\ciphertext.txt','wb')
# f.write(bytes(encrypted_text))
# f.close()
# ```
# 2. Опція вибору методу зчеплення та генерації випадкового початкового значення `iv` за необхідності - **до 10 балів**
# 3. Метод, що генерує значення ключа сесії (128 біт) та зберігає його у відповідному атрибуті класу - **до 10 балів**
# 4. Модифікація методу, що створює ключ шифрування довжиною 256 біт для більшого захисту шифрування - **до 5 балів**
# 5. Метод, що зберігає значення ключа шифрування у файлі - **до 5 балів**
# 6. Створення єдиного класу, що вміє шифрувати і розшифровувати повідомлення і його наслідування відправником і отримувачем - **до 10 балів**
